# %%
import pandas as pd
import numpy as np

# %%
data  = "ipl_matches_data.xlsx"
Ipl_Century = "ipl_centuries.xlsx"
Team_Data = "teams_data.xlsx"
Player_Data = "players-data-updated.xlsx"

# %%
# ==========================
# Data 1  ipl_matches_data
# ==========================

df = pd.read_excel(data)
df.head()
# Out:
#    season_id  balls_per_over        city match_date             event_name  \
# 0       2008               6   Bangalore 2008-04-18  Indian Premier League
# 1       2008               6  Chandigarh 2008-04-19  Indian Premier League
# 2       2008               6       Delhi 2008-04-19  Indian Premier League
# 3       2008               6      Mumbai 2008-04-20  Indian Premier League
# 4       2008               6     Kolkata 2008-04-20  Indian Premier League
#
#    match_number gender match_type format  overs  ...  \
# 0           1.0   male        T20    T20     20  ...
# 1           2.0   male        T20    T20     20  ...
# 2           3.0   male        T20    T20     20  ...
# 3           5.0   male        T20    T20     20  ...
# 4           4.0   male        T20    T20     20  ...
#
#                    toss_winner                        team1  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore
# 1          Chennai Super Kings                 Punjab Kings
# ...

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-7c7b1cdf-1e9c-4c9e-a84a-7759e5273dd7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7c7b1cdf-1e9c-4c9e-a84a-7759e5273dd7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1169 entries, 0 to 1168
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   season_id        1169 non-null   int64
#  1   balls_per_over   1169 non-null   int64
#  2   city             1118 non-null   str
#  3   match_date       1169 non-null   datetime64[us]
#  4   event_name       1169 non-null   str
#  5   match_number     1099 non-null   float64
#  6   gender           1169 non-null   str
#  7   match_type       1169 non-null   str
#  8   format           1169 non-null   str
#  9   overs            1169 non-null   int64
#  10  season           1169 non-null   object
#  11  team_type        1169 non-null   str
#  12  venue            1169 non-null   str
#  13  toss_winner      1168 non-null   str
#  14  team1            1169 non-null   str
#  15  team2            1169 non-null   str
#  16  toss_decision    1168 non-null   str
# ...

# %%
df.describe()
# Out:
#          season_id  balls_per_over                  match_date  match_number  \
# count  1169.000000          1169.0                        1169   1099.000000
# mean   2016.687767             6.0  2017-01-15 13:04:40.239521     31.705187
# min    2008.000000             6.0         2008-04-18 00:00:00      1.000000
# 25%    2012.000000             6.0         2012-05-05 00:00:00     16.000000
# 50%    2017.000000             6.0         2017-04-10 00:00:00     31.000000
# 75%    2022.000000             6.0         2022-03-26 00:00:00     47.000000
# max    2025.000000             6.0         2025-06-03 00:00:00     72.000000
# std       5.253100             0.0                         NaN     18.518304
#
#         overs  win_by_runs  win_by_wickets  player_of_match
# count  1169.0   531.000000      615.000000      1161.000000
# mean     20.0    30.295669        6.200000      3274.304048
# min      20.0     1.000000        1.000000         1.000000
# ...

# %%
df.tail()
# Out:
#       season_id  balls_per_over            city match_date  \
# 1164       2025               6  New Chandigarh 2025-05-30
# 1165       2025               6       Ahmedabad 2025-06-01
# 1166       2025               6       Ahmedabad 2025-06-03
# 1167       2025               6          Jaipur 2025-05-24
# 1168       2025               6       Bengaluru 2025-05-17
#
#                  event_name  match_number gender   match_type format  overs  \
# 1164  Indian Premier League           NaN   male   Eliminator    T20     20
# 1165  Indian Premier League           NaN   male  Qualifier 2    T20     20
# 1166  Indian Premier League           NaN   male        Final    T20     20
# 1167  Indian Premier League          66.0   male          T20    T20     20
# 1168  Indian Premier League          71.0   male          T20    T20     20
#
#       ...     toss_winner                        team1                  team2  \
# ...

# %%
print(df.columns)
# Out:
# Index(['season_id', 'balls_per_over', 'city', 'match_date', 'event_name',
#        'match_number', 'gender', 'match_type', 'format', 'overs', 'season',
#        'team_type', 'venue', 'toss_winner', 'team1', 'team2', 'toss_decision',
#        'match_winner', 'win_by_runs', 'win_by_wickets', 'player_of_match',
#        'result', 'stage'],
#       dtype='str')

# %%
df.shape
# Out:
# (1169, 23)

# %%
df.isnull()
# Out:
#       season_id  balls_per_over   city  match_date  event_name  match_number  \
# 0         False           False  False       False       False         False
# 1         False           False  False       False       False         False
# 2         False           False  False       False       False         False
# 3         False           False  False       False       False         False
# 4         False           False  False       False       False         False
# ...         ...             ...    ...         ...         ...           ...
# 1164      False           False  False       False       False          True
# 1165      False           False  False       False       False          True
# 1166      False           False  False       False       False          True
# 1167      False           False  False       False       False         False
# 1168      False           False  False       False       False         False
#
# ...

# %%
df.isnull().sum()
# Out:
# season_id             0
# balls_per_over        0
# city                 51
# match_date            0
# event_name            0
# match_number         70
# gender                0
# match_type            0
# format                0
# overs                 0
# season                0
# team_type             0
# venue                 0
# toss_winner           1
# team1                 0
# team2                 0
# toss_decision         1
# match_winner          8
# win_by_runs         638
# win_by_wickets      554
# player_of_match       8
# result                0
# stage              1165
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1164    False
# 1165    False
# 1166    False
# 1167    False
# 1168    False
# Length: 1169, dtype: bool

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [season_id, balls_per_over, city, match_date, event_name, match_number, gender, match_type, format, overs, season, team_type, venue, toss_winner, team1, team2, toss_decision, match_winner, win_by_runs, win_by_wickets, player_of_match, result, stage]
# Index: []
#
# [0 rows x 23 columns]

# %%
df.fillna(0)
# Out:
#       season_id  balls_per_over            city match_date  \
# 0          2008               6       Bangalore 2008-04-18
# 1          2008               6      Chandigarh 2008-04-19
# 2          2008               6           Delhi 2008-04-19
# 3          2008               6          Mumbai 2008-04-20
# 4          2008               6         Kolkata 2008-04-20
# ...         ...             ...             ...        ...
# 1164       2025               6  New Chandigarh 2025-05-30
# 1165       2025               6       Ahmedabad 2025-06-01
# 1166       2025               6       Ahmedabad 2025-06-03
# 1167       2025               6          Jaipur 2025-05-24
# 1168       2025               6       Bengaluru 2025-05-17
#
#                  event_name  match_number gender   match_type format  overs  \
# 0     Indian Premier League           1.0   male          T20    T20     20
# 1     Indian Premier League           2.0   male          T20    T20     20
# ...

# %%
# Before replacing
print("AVG. Wins By Runs")
print(int(df['win_by_runs'].mean()))

print("AVG. Wins By Wickets")
print(int(df['win_by_wickets'].mean()))
# Out:
# AVG. Wins By Runs
# 30
# AVG. Wins By Wickets
# 6

# %%
#fill 0's
df['win_by_runs'] = df['win_by_runs'].replace(0, df['win_by_runs'].mean())

df['win_by_wickets']= df['win_by_wickets'].replace(0, df['win_by_wickets'].mean())

# %%
# After replacing

print("AVG. Wins By Runs")
print(int(df['win_by_runs'].mean()))

print("AVG. Wins By Wickets")
print(int(df['win_by_wickets'].mean()))
# Out:
# AVG. Wins By Runs
# 30
# AVG. Wins By Wickets
# 6

# %%
# ==========================
# Data 2  Ipl_Century = "ipl_centuries.xlsx"
# ==========================

df = pd.read_excel(Ipl_Century)
df.head()
# Out:
#    No Score  Balls  Strike Rate             Player                   Team  \
# 0   1  158*     73       216.43   Brendon McCullum  Kolkata Knight Riders
# 1   2  116*     54       214.81     Michael Hussey    Chennai Super Kings
# 2   3  117*     53       220.75     Andrew Symonds        Deccan Chargers
# 3   4  109*     47       231.91     Adam Gilchrist        Deccan Chargers
# 4   5  114*     48       237.50  Sanath Jayasuriya         Mumbai Indians
#
#                     Opposition  Innings  \
# 0  Royal Challengers Bangalore        1
# 1              Kings XI Punjab        1
# 2             Rajasthan Royals        1
# 3               Mumbai Indians        2
# 4          Chennai Super Kings        2
#
#                                         Venue        City       Date Result
# 0                      M. Chinnaswamy Stadium   Bangalore 2008-04-18    Won
# 1                                 PCA Stadium      Mohali 2008-04-19    Won
# ...

# %%
df.tail()
# Out:
#       No Score  Balls  Strike Rate               Player                  Team  \
# 103  104   141     55       256.36      Abhishek Sharma   Sunrisers Hyderabad
# 104  105   101     38       265.78  Vaibhav Suryavanshi      Rajasthan Royals
# 105  106  112*     65       172.30             KL Rahul        Delhi Capitals
# 106  107  108*     61       177.04        Sai Sudharsan        Gujarat Titans
# 107  108   117     64       182.81       Mitchell Marsh  Lucknow Super Giants
#
#          Opposition  Innings                                       Venue  \
# 103    Punjab Kings        2  Rajiv Gandhi International Cricket Stadium
# 104  Gujarat Titans        2                      Sawai Mansingh Stadium
# 105  Gujarat Titans        1                Arun Jaitley Cricket Stadium
# 106  Delhi Capitals        2                Arun Jaitley Cricket Stadium
# 107  Gujarat Titans        1                       Narendra Modi Stadium
#
#            City       Date Result
# ...

# %%
df.columns
# Out:
# Index(['team_id', 'team_name', 'team_name_short', 'image_url'], dtype='str')

# %%
df.shape
# Out:
# (16, 4)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   No           108 non-null    int64
#  1   Score        108 non-null    object
#  2   Balls        108 non-null    int64
#  3   Strike Rate  108 non-null    float64
#  4   Player       108 non-null    str
#  5   Team         108 non-null    str
#  6   Opposition   108 non-null    str
#  7   Innings      108 non-null    int64
#  8   Venue        108 non-null    str
#  9   City         108 non-null    str
#  10  Date         108 non-null    datetime64[us]
#  11  Result       108 non-null    str
# dtypes: datetime64[us](1), float64(1), int64(3), object(1), str(6)
# memory usage: 7.2+ KB

# %%
df.describe()
# Out:
#               No       Balls  Strike Rate     Innings                 Date
# count  108.00000  108.000000   108.000000  108.000000                  108
# mean    54.50000   57.564815   193.671296    1.324074  2018-05-14 23:46:40
# min      1.00000   37.000000   147.050000    1.000000  2008-04-18 00:00:00
# 25%     27.75000   54.000000   172.410000    1.000000  2013-05-05 00:00:00
# 50%     54.50000   58.000000   188.985000    1.000000  2019-03-31 00:00:00
# 75%     81.25000   63.000000   210.235000    2.000000  2023-05-15 18:00:00
# max    108.00000   73.000000   270.270000    2.000000  2025-05-22 00:00:00
# std     31.32092    7.236038    28.050840    0.470210                  NaN

# %%
df.isnull()
# Out:
#         No  Score  Balls  Strike Rate  Player   Team  Opposition  Innings  \
# 0    False  False  False        False   False  False       False    False
# 1    False  False  False        False   False  False       False    False
# 2    False  False  False        False   False  False       False    False
# 3    False  False  False        False   False  False       False    False
# 4    False  False  False        False   False  False       False    False
# ..     ...    ...    ...          ...     ...    ...         ...      ...
# 103  False  False  False        False   False  False       False    False
# 104  False  False  False        False   False  False       False    False
# 105  False  False  False        False   False  False       False    False
# 106  False  False  False        False   False  False       False    False
# 107  False  False  False        False   False  False       False    False
#
#      Venue   City   Date  Result
# 0    False  False  False   False
# ...

# %%
df.isnull().sum()
# Out:
# No             0
# Score          0
# Balls          0
# Strike Rate    0
# Player         0
# Team           0
# Opposition     0
# Innings        0
# Venue          0
# City           0
# Date           0
# Result         0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 103    False
# 104    False
# 105    False
# 106    False
# 107    False
# Length: 108, dtype: bool

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
print("Avg. Balls Taken to Score Cenntury: ", int(df['Balls'].mean()) )
print()

print("Max. Balls Taken to Score Cenntury: ",int(df['Balls'].max()) )
print()

print("min. Balls Taken to Score Cenntury: ",int(df['Balls'].min()) )
print()

print("Avg. Strike Rate: " , int(df['Strike Rate'].mean()) )
print()

print("max Strike Rate: " , int(df['Strike Rate'].max()) )
print()

print("min Strike Rate: " , int(df['Strike Rate'].min()))
print()
# Out:
# Avg. Balls Taken to Score Cenntury:  57
#
# Max. Balls Taken to Score Cenntury:  73
#
# min. Balls Taken to Score Cenntury:  37
#
# Avg. Strike Rate:  193
#
# max Strike Rate:  270
#
# min Strike Rate:  147

# %%
# ==========================
# Data 3  Team_Data = "teams_data"
# ==========================

df = pd.read_excel(Team_Data)
df.head()
# Out:
#    team_id                    team_name team_name_short  \
# 0        1  Royal Challengers Bangalore             RCB
# 1        2          Sunrisers Hyderabad             SRH
# 2        3               Mumbai Indians              MI
# 3        4       Rising Pune Supergiant             RPS
# 4        5                Gujarat Lions              GL
#
#                                            image_url
# 0  https://documents.iplt20.com/ipl/RCB/Logos/Log...
# 1  https://documents.iplt20.com/ipl/SRH/Logos/Log...
# 2  https://documents.iplt20.com/ipl/MI/Logos/Logo...
# 3  https://ipl-stats-sports-mechanic.s3.ap-south-...
# 4  https://ipl-stats-sports-mechanic.s3.ap-south-...

# %%
df.tail()
# Out:
#     team_id                team_name team_name_short  \
# 11      615           Gujarat Titans              GT
# 12     1068          Deccan Chargers             DEC
# 13     1414     Kochi Tuskers Kerala             KTK
# 14     1419            Pune Warriors             PWI
# 15     3604  Rising Pune Supergiants             RPS
#
#                                             image_url
# 11  https://documents.iplt20.com/ipl/GT/Logos/Logo...
# 12  https://ipl-stats-sports-mechanic.s3.ap-south-...
# 13  https://ipl-stats-sports-mechanic.s3.ap-south-...
# 14  https://ipl-stats-sports-mechanic.s3.ap-south-...
# 15  https://ipl-stats-sports-mechanic.s3.ap-south-...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   team_id          16 non-null     int64
#  1   team_name        16 non-null     str
#  2   team_name_short  16 non-null     str
#  3   image_url        16 non-null     str
# dtypes: int64(1), str(3)
# memory usage: 392.0 bytes

# %%
df.shape
# Out:
# (16, 4)

# %%
df.columns
# Out:
# Index(['team_id', 'team_name', 'team_name_short', 'image_url'], dtype='str')

# %%
df.describe()
# Out:
#           team_id
# count    16.00000
# mean    610.25000
# std     940.96989
# min       1.00000
# 25%       4.75000
# 50%     193.00000
# 75%     728.25000
# max    3604.00000

# %%
df.isnull()
# Out:
#     team_id  team_name  team_name_short  image_url
# 0     False      False            False      False
# 1     False      False            False      False
# 2     False      False            False      False
# 3     False      False            False      False
# 4     False      False            False      False
# 5     False      False            False      False
# 6     False      False            False      False
# 7     False      False            False      False
# 8     False      False            False      False
# 9     False      False            False      False
# 10    False      False            False      False
# 11    False      False            False      False
# 12    False      False            False      False
# 13    False      False            False      False
# 14    False      False            False      False
# 15    False      False            False      False

# %%
df.isnull().sum()
# Out:
# team_id            0
# team_name          0
# team_name_short    0
# image_url          0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# dtype: bool

# %%
print(df.duplicated().sum())
# Out:
# 0

# %%
print(df['team_name'])
# Out:
# 0     Royal Challengers Bangalore
# 1             Sunrisers Hyderabad
# 2                  Mumbai Indians
# 3          Rising Pune Supergiant
# 4                   Gujarat Lions
# 5           Kolkata Knight Riders
# 6             Chennai Super Kings
# 7                Rajasthan Royals
# 8                  Delhi Capitals
# 9                    Punjab Kings
# 10           Lucknow Super Giants
# 11                 Gujarat Titans
# 12                Deccan Chargers
# 13           Kochi Tuskers Kerala
# 14                  Pune Warriors
# 15        Rising Pune Supergiants
# Name: team_name, dtype: str

# %%
# ==========================
# Data 4 Player_Data = "players-data-updated.xlsx"
# ==========================

df = pd.read_excel(Player_Data)
df.head()
# Out:
#    player_id    player_name       bat_style             bowl_style  \
# 0          1       CH Gayle   Left hand Bat     Right arm Offbreak
# 1          2  Mandeep Singh  Right hand Bat       Right arm Medium
# 2          3        TM Head   Left hand Bat     Right arm Offbreak
# 3          4      KM Jadhav  Right hand Bat     Right arm Offbreak
# 4          5      SR Watson  Right hand Bat  Right arm Fast medium
#
#       field_pos         player_full_name       player_name2  \
# 0                Christopher Henry Gayle  Christopher Henry
# 1                          Mandeep Singh      Mandeep Singh
# 2  Wicketkeeper      Travis Michael Head     Travis Michael
# 3                   Kedar Mahadav Jadhav      Kedar Mahadav
# 4                    Shane Robert Watson       Shane Robert
#
#                                         player_image
# 0  https://ipl-stats-sports-mechanic.s3.ap-south-...
# 1                                                NaN
# ...

# %%
df.tail()
# Out:
#      player_id      player_name       bat_style              bowl_style  \
# 767      43649      Harsh Dubey   Left hand Bat  Slow Left arm Orthodox
# 768      43820      MP Breetzke  Right hand Bat                     NaN
# 769      43849     Musheer Khan  Right hand Bat  Slow Left arm Orthodox
# 770      43881       BKG Mendis  Right hand Bat                Legbreak
# 771      43954  Sediqullah Atal   Left hand Bat                     NaN
#
#         field_pos       player_full_name     player_name2  \
# 767           NaN   Harsh Surendra Dubey   Harsh Surendra
# 768  Wicketkeeper  Matthew Paul Breetzke     Matthew Paul
# 769           NaN           Musheer Khan     Musheer Khan
# 770           NaN           Kusal Mendis     Kusal Mendis
# 771           NaN        Sediqullah Atal  Sediqullah Atal
#
#                                           player_image
# 767                                                NaN
# 768                                                NaN
# ...

# %%
df.shape
# Out:
# (772, 8)

# %%
df.columns
# Out:
# Index(['player_id', 'player_name', 'bat_style', 'bowl_style', 'field_pos',
#        'player_full_name', 'player_name2', 'player_image'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 772 entries, 0 to 771
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   player_id         772 non-null    int64
#  1   player_name       772 non-null    str
#  2   bat_style         772 non-null    str
#  3   bowl_style        759 non-null    str
#  4   field_pos         707 non-null    str
#  5   player_full_name  772 non-null    str
#  6   player_name2      772 non-null    str
#  7   player_image      134 non-null    str
# dtypes: int64(1), str(7)
# memory usage: 27.2 KB

# %%
df.describe()
# Out:
#           player_id
# count    772.000000
# mean   11085.305699
# std    11339.197705
# min        1.000000
# 25%     2016.750000
# 50%     9516.000000
# 75%    13385.000000
# max    43954.000000

# %%
df.isnull()
# Out:
#      player_id  player_name  bat_style  bowl_style  field_pos  \
# 0        False        False      False       False      False
# 1        False        False      False       False      False
# 2        False        False      False       False      False
# 3        False        False      False       False      False
# 4        False        False      False       False      False
# ..         ...          ...        ...         ...        ...
# 767      False        False      False       False       True
# 768      False        False      False        True      False
# 769      False        False      False       False       True
# 770      False        False      False       False       True
# 771      False        False      False        True       True
#
#      player_full_name  player_name2  player_image
# 0               False         False         False
# 1               False         False          True
# 2               False         False         False
# ...

# %%
df.isnull().sum()
# Out:
# player_id             0
# player_name           0
# bat_style             0
# bowl_style           13
# field_pos            65
# player_full_name      0
# player_name2          0
# player_image        638
# dtype: int64

# %%
df.fillna('NA')
# Out:
#      player_id      player_name       bat_style              bowl_style  \
# 0            1         CH Gayle   Left hand Bat      Right arm Offbreak
# 1            2    Mandeep Singh  Right hand Bat        Right arm Medium
# 2            3          TM Head   Left hand Bat      Right arm Offbreak
# 3            4        KM Jadhav  Right hand Bat      Right arm Offbreak
# 4            5        SR Watson  Right hand Bat   Right arm Fast medium
# ..         ...              ...             ...                     ...
# 767      43649      Harsh Dubey   Left hand Bat  Slow Left arm Orthodox
# 768      43820      MP Breetzke  Right hand Bat                      NA
# 769      43849     Musheer Khan  Right hand Bat  Slow Left arm Orthodox
# 770      43881       BKG Mendis  Right hand Bat                Legbreak
# 771      43954  Sediqullah Atal   Left hand Bat                      NA
#
#         field_pos         player_full_name       player_name2  \
# ...

# %%
df.isnull().sum()
# Out:
# player_id             0
# player_name           0
# bat_style             0
# bowl_style           13
# field_pos            65
# player_full_name      0
# player_name2          0
# player_image        638
# dtype: int64

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 767    False
# 768    False
# 769    False
# 770    False
# 771    False
# Length: 772, dtype: bool

# %%
print(df.duplicated().sum())
# Out:
# 0
